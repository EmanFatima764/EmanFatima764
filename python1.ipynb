# %% [markdown]
# <a href="https://colab.research.google.com/github/EmanFatima764/EmanFatima764/blob/main/python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1- Write a program to input two numbers & print their sums.
#
#
# ---

# %%
a=int(input("Enter a number : "))
b=int(input("Enter a number : "))
sum=a+b
print(sum)
# Out:
# Enter a number : 3
# Enter a number : 4
# 7

# %% [markdown]
# 2- Write a program to input two floating point numbers and print their average.

# %%
a=float(input("Enter a number : "))
b=float(input("Enter a number : "))
avg=(a+b)/2
print(avg)
# Out:
# Enter a number : 5
# Enter a number : 6
# 5.5

# %% [markdown]
# Write a program to input two integer numbers a and b. Print True if a is greater than or equal to b. If not print False.

# %%
a=int(input("Enter a number : "))
b=int(input("Enter a number : "))
if a>=b:
  print("True")
else:
  print("False")
# Out:
# Enter a number : 34
# Enter a number : 56
# False

# %% [markdown]
# Write a program to input side of a square and print its area.
#
#
#
# ---

# %%
x=int(input("Enter a number :"))
area=x*x
print(f"Area of square is {area}")
# Out:
# Enter a number :3
# Area of square is9
